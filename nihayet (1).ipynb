# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Abdullah Ötük</b>
# <p>Data scientist</p>

# %% [markdown]
# <i>I like Numbers and Data because I am a Mathematician</i>

# %% [markdown]
# <h3>Circumference formula of a circle</h3>

# %%
import math
def Circle(r):
    return 2*math.pi*r
Circle(15)
# Out:
# 94.24777960769379

# %% [markdown]
# <a href="http://www.ibm.com"> www.ibm.com </a>

# %% [markdown]
# <table border=1 bordercolor="Blue">
#   <tr>
#     <th>Continent</th>
#     <th>America</th>
#     <th>Europe</th>
#     <th>Asia</th>
#     </tr>
#   <tr>
#     <td>Country</td>
#     <td>Chinese</td>
#     <td>Germany</td>
#     <td>Canada</td>
#      </tr>
#   </table>

# %% [markdown]
# <p>
# <ul>
# <li>Watermelon</li>
# <li>Steak</li>
# <li>Rice</li>
# <li>The Fish</li>
# </ul>
# </p>
